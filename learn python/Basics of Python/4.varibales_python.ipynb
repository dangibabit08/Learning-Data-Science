# %%
# No varibale declaration in  python
# Dynamic TYping 
# Dynamic Binding

# %%
name="Babit"
print(name)
# Out:
# Babit

# %%
name=10
print(name)
# Out:
# 10

# %%
#special syntax

a=5;b=10;c="babit"
print(a)
print(b)
print(c)
# Out:
# 5
# 10
# babit

# %%
a,b,c=5,10,"Babit"
print(a)
print(b)
print(c)
# Out:
# 5
# 10
# Babit

# %%
a=b=c=6
print(a)
print(b)
print(c)
# Out:
# 6
# 6
# 6

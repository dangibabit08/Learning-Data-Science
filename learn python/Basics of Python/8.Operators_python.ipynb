# %%
#sum of digits of 3 digit number

number=int(input("enter the three digit number:"))
a=number%10
number=number // 10

b=number%10
number = number//10

c=number % 10
print(a+b+c)
# Out:
# enter the three digit number: 987
# 24

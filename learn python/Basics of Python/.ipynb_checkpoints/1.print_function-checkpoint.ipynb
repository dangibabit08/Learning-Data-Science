# %%
print("hello world")
# Out:
# hello world

# %%
print(56)
# Out:
# 56

# %%
print(5.67)
# Out:
# 5.67

# %%
print(False)
# Out:
# False

# %%
print("saugat","ram",5,False)
# Out:
# saugat ram 5 False

# %%
print("saugat","ram",5,False,sep="-")
# Out:
# saugat-ram-5-False

# %%
print("hello")      #by default end="/n"
print("world")
# Out:
# hello
# world

# %%
print("hello" ,end=" ")   #here i change end="/n" to end=" "
print("world")
# Out:
# hello world

# %%
name="abc"
if name=="abc":
print("line 1")
else:
print("line 2")
# Out:
#   Cell In[2], line 3
#     print("line 1")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
name="abc"
if name=="abc":
    print("line 1")
else:
    print("line 2")
# Out:
# line 1

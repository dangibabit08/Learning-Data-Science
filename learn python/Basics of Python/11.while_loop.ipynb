# %%
#while loop syntax
"""
while condition:
     code
"""
# Out:
# '\nwhile condition:\n     code\n'

# %%
# printing the table of any number 

number =int(input("enter the number:"))
i=1

while i<=10:
    print(number * i)
    i+=1
# Out:
# enter the number: 11
# 11
# 22
# 33
# 44
# 55
# 66
# 77
# 88
# 99
# 110
